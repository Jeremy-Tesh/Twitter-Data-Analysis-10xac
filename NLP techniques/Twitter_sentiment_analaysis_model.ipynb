# %%
# !pip3 install gensim
# !pip3 install pyLDAvis
# !pip3 install numpy
# !pip3 install wordcloud



import pandas as pd
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
# Out:
# Requirement already satisfied: gensim in /home/ermi/anaconda3/lib/python3.9/site-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /home/ermi/anaconda3/lib/python3.9/site-packages (from gensim) (1.20.3)
# Requirement already satisfied: smart-open>=1.8.1 in /home/ermi/anaconda3/lib/python3.9/site-packages (from gensim) (6.0.0)
# Requirement already satisfied: scipy>=0.18.1 in /home/ermi/anaconda3/lib/python3.9/site-packages (from gensim) (1.7.1)
# Requirement already satisfied: pyLDAvis in /home/ermi/anaconda3/lib/python3.9/site-packages (3.3.1)
# Requirement already satisfied: funcy in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: numexpr in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: future in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: pandas>=1.2.0 in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (1.3.4)
# Requirement already satisfied: numpy>=1.20.0 in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (1.20.3)
# Requirement already satisfied: gensim in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (4.1.2)
# Requirement already satisfied: setuptools in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (58.0.4)
# Requirement already satisfied: scikit-learn in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (0.24.2)
# Requirement already satisfied: sklearn in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: scipy in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (1.7.1)
# Requirement already satisfied: joblib in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: jinja2 in /home/ermi/anaconda3/lib/python3.9/site-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ermi/anaconda3/lib/python3.9/site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/ermi/anaconda3/lib/python3.9/site-packages (from pandas>=1.2.0->pyLDAvis) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/ermi/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: smart-open>=1.8.1 in /home/ermi/anaconda3/lib/python3.9/site-packages (from gensim->pyLDAvis) (6.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ermi/anaconda3/lib/python3.9/site-packages (from jinja2->pyLDAvis) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ermi/anaconda3/lib/python3.9/site-packages (from scikit-learn->pyLDAvis) (2.2.0)
# Requirement already satisfied: numpy in /home/ermi/anaconda3/lib/python3.9/site-packages (1.20.3)
# Requirement already satisfied: wordcloud in /home/ermi/anaconda3/lib/python3.9/site-packages (1.8.1)
# Requirement already satisfied: matplotlib in /home/ermi/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: pillow in /home/ermi/anaconda3/lib/python3.9/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in /home/ermi/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in /home/ermi/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ermi/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ermi/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ermi/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: six in /home/ermi/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/ermi/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = pd.read_csv('../cleaned_tweet_data.csv')

# %%
df.head()
# Out:
#                   created_at  \
# 0  2022-04-22 22:17:05+00:00
# 1  2022-04-22 13:44:53+00:00
# 2  2022-04-22 06:10:34+00:00
# 3  2022-04-21 17:22:09+00:00
# 4  2022-04-21 10:32:26+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                        original_text  polarity  subjectivity  \
# 0  RT @NorthstarCharts: The 10-year yield is tell...      0.16      0.540000
# 1  RT @MichaelAArouet: German 10y mortgage rate w...       NaN      0.175000
# 2        RT @goldseek: When? https://t.co/kO2FfHKaZg      0.00      0.000000
# 3  RT @charliebilello: The 30-year mortgage rate ...      0.00      0.183333
# 4  RT @biancoresearch: Rates rise until something...     -0.40      0.400000
#
#   lang  favorite_count  retweet_count  original_author  followers_count  \
# 0   en           188.0           43.0  davideiacovozzi               18
# 1   en             NaN            NaN  davideiacovozzi               18
# 2   en           193.0           26.0  davideiacovozzi               18
# 3   en           620.0          213.0  davideiacovozzi               18
# 4   en          1787.0          417.0  davideiacovozzi               18
#
#    friends_count possibly_sensitive  \
# 0             18                NaN
# 1             18                NaN
# 2             18              False
# 3             18                NaN
# 4             18              False
#
#                                             hashtags  \
# 0  [{'text': 'gold', 'indices': [116, 121]}, {'te...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                        user_mentions place
# 0  [{'screen_name': 'NorthstarCharts', 'name': 'N...   NaN
# 1  [{'screen_name': 'MichaelAArouet', 'name': 'Mi...   NaN
# 2  [{'screen_name': 'goldseek', 'name': 'Peter ⚒ ...   NaN
# 3  [{'screen_name': 'charliebilello', 'name': 'Ch...   NaN
# 4  [{'screen_name': 'biancoresearch', 'name': 'Ji...   NaN

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

df['original_text'][0]

# convert all original_text fields to strings
df['original_text'] = df['original_text'].astype(str)
df['clean_text'] = df['original_text'].str.replace('[^\w\s]','')
df['clean_text'] = df['clean_text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['clean_text'] = df['clean_text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
# re.sub('\w*\d\w*', '', text)
df['clean_text'] = df['clean_text'].str.replace('\w*\d\w*','')
# df.head()


# normally we tokenize using words so each word as a token
#Lines 4 to 6
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
df['clean_text'] = df['clean_text'].apply(lambda x: " ".join([stemmer.stem(word) for word in x.split()]))

df[['polarity','original_text','clean_text']].head()
# Out:
# /tmp/ipykernel_25793/3730894449.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['clean_text'] = df['original_text'].str.replace('[^\w\s]','')
# /tmp/ipykernel_25793/3730894449.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['clean_text'] = df['clean_text'].str.replace('\w*\d\w*','')
#    polarity                                      original_text  \
# 0      0.16  RT @NorthstarCharts: The 10-year yield is tell...
# 1       NaN  RT @MichaelAArouet: German 10y mortgage rate w...
# 2      0.00        RT @goldseek: When? https://t.co/kO2FfHKaZg
# 3      0.00  RT @charliebilello: The 30-year mortgage rate ...
# 4     -0.40  RT @biancoresearch: Rates rise until something...
#
#                                           clean_text
# 0  rt northstarchart the yield tell us there high...
# 1  rt michaelaarouet german mortgag rate went can...
# 2                                   rt goldseek when
# 3  rt charliebilello the mortgag rate us rise hig...
# 4  rt biancoresearch rate rise someth break anyth...

# %%
for index, row in df['clean_text'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    if score['neg'] > score['pos']:
        df.loc[index, "sentiment"] = "negative"
    elif score['pos'] > score['neg']:
        df.loc[index, "sentiment"] = "positive"
    else:
        df.loc[index, "sentiment"] = "neutral"
        
    df.loc[index, 'neg'] = score['neg']
    df.loc[index, 'neu'] = score['neu']
    df.loc[index, 'pos'] = score['pos']
    
df.head(10)
# Out:
#                   created_at  \
# 0  2022-04-22 22:17:05+00:00
# 1  2022-04-22 13:44:53+00:00
# 2  2022-04-22 06:10:34+00:00
# 3  2022-04-21 17:22:09+00:00
# 4  2022-04-21 10:32:26+00:00
# 5  2022-04-19 10:59:33+00:00
# 6  2022-04-19 10:58:15+00:00
# 7  2022-04-18 09:31:42+00:00
# 8  2022-04-17 22:04:00+00:00
# 9  2022-04-17 18:21:46+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="http://twitter.com/download/android" ...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://twitter.com/download/android" ...
# 8  <a href="http://twitter.com/download/android" ...
# 9  <a href="http://twitter.com/download/android" ...
#
#                                        original_text  polarity  subjectivity  \
# 0  RT @NorthstarCharts: The 10-year yield is tell...  0.160000      0.540000
# 1  RT @MichaelAArouet: German 10y mortgage rate w...       NaN      0.175000
# 2        RT @goldseek: When? https://t.co/kO2FfHKaZg  0.000000      0.000000
# 3  RT @charliebilello: The 30-year mortgage rate ...  0.000000      0.183333
# 4  RT @biancoresearch: Rates rise until something... -0.400000      0.400000
# 5  RT @LanceRoberts: Buying opportunities like th... -0.100000      0.550000
# 6  RT @MacroAlf: Welcome to September 2018.\n\nBo...  0.400000      0.637500
# 7  RT @BotBenFranklin: The horse thinks one thing...  0.000000      0.000000
# 8  RT @Galactic_Trader: Global growth optimism at...  0.488281      0.250000
# 9  RT @AndreasSteno: This is the most important c...  0.450000      0.750000
#
#   lang  favorite_count  retweet_count  original_author  followers_count  \
# 0   en           188.0           43.0  davideiacovozzi               18
# 1   en             NaN            NaN  davideiacovozzi               18
# 2   en           193.0           26.0  davideiacovozzi               18
# 3   en           620.0          213.0  davideiacovozzi               18
# 4   en          1787.0          417.0  davideiacovozzi               18
# 5   en          1156.0          162.0  davideiacovozzi               18
# 6   en           802.0           45.0  davideiacovozzi               18
# 7   en            18.0            4.0  davideiacovozzi               18
# 8   en            49.0            4.0  davideiacovozzi               18
# 9   en           882.0          176.0  davideiacovozzi               18
#
#    friends_count possibly_sensitive  \
# 0             18                NaN
# 1             18                NaN
# 2             18              False
# 3             18                NaN
# 4             18              False
# 5             18              False
# 6             18                NaN
# 7             18                NaN
# 8             18                NaN
# 9             18                NaN
#
#                                             hashtags  \
# 0  [{'text': 'gold', 'indices': [116, 121]}, {'te...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5           [{'text': 'bonds', 'indices': [78, 84]}]
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                        user_mentions place  \
# 0  [{'screen_name': 'NorthstarCharts', 'name': 'N...   NaN
# 1  [{'screen_name': 'MichaelAArouet', 'name': 'Mi...   NaN
# 2  [{'screen_name': 'goldseek', 'name': 'Peter ⚒ ...   NaN
# 3  [{'screen_name': 'charliebilello', 'name': 'Ch...   NaN
# 4  [{'screen_name': 'biancoresearch', 'name': 'Ji...   NaN
# 5  [{'screen_name': 'LanceRoberts', 'name': 'Lanc...   NaN
# 6  [{'screen_name': 'MacroAlf', 'name': 'Alf', 'i...   NaN
# 7  [{'screen_name': 'BotBenFranklin', 'name': 'Be...   NaN
# 8  [{'screen_name': 'Galactic_Trader', 'name': 'J...   NaN
# 9  [{'screen_name': 'AndreasSteno', 'name': 'Andr...   NaN
#
#                                           clean_text sentiment    neg    neu  \
# 0  rt northstarchart the yield tell us there high...  negative  0.130  0.870
# 1  rt michaelaarouet german mortgag rate went can...   neutral  0.000  1.000
# 2                                   rt goldseek when   neutral  0.000  1.000
# 3  rt charliebilello the mortgag rate us rise hig...  negative  0.130  0.870
# 4  rt biancoresearch rate rise someth break anyth...  negative  0.279  0.721
# 5  rt lancerobert buy opportun like occur everi y...  positive  0.000  0.783
# 6  rt macroalf welcom septemb bond market test ri...  positive  0.119  0.739
# 7  rt botbenfranklin the hors think one thing sad...   neutral  0.000  1.000
# 8  rt galactic_trad global growth optim time low ...  positive  0.126  0.719
# 9  rt andreassteno thi import chart world demand ...  negative  0.214  0.786
#
#      pos
# 0  0.000
# 1  0.000
# 2  0.000
# 3  0.000
# 4  0.000
# 5  0.217
# 6  0.142
# 7  0.000
# 8  0.156
# 9  0.000

# %%
tweet_neg = df[df["sentiment"] == "negative"]
tweet_neu = df[df["sentiment"] == "neutral"]
tweet_pos = df[df["sentiment"] == "positive"]
#function for calculating the percentage of all the sentiments
def calc_percentage(x,y):
    return x/y * 100
pos_per = calc_percentage(len(tweet_pos), len(df))
neg_per = calc_percentage(len(tweet_neg), len(df))
neu_per = calc_percentage(len(tweet_neu), len(df))


print("positive: {} {}%".format(len(tweet_pos),  format(pos_per, '.1f')))
print("negative: {} {}%".format(len(tweet_neg), format(neg_per, '.1f')))
print("neutral: {} {}%".format(len(tweet_neu), format(neu_per, '.1f')))
# Out:
# positive: 5597 34.2%
# negative: 3578 21.9%
# neutral: 7192 43.9%

# %%
labels = df.groupby('sentiment').count().index.values
values = df.groupby('sentiment').size().values
plt.bar(labels, values)
# Out:
# <BarContainer object of 3 artists>

# %%
labels = ['Positive ['+format(pos_per, '.1f')+'%]', 'Neutral ['+format(neu_per,'.1f')+'%]', 'Negative ['+format(neg_per,'.1f')+'%]']
sizes = [len(tweet_pos), len(tweet_neu), len(tweet_neg)]
colors = ['green', 'blue', 'red']
patches, texts = plt.pie(sizes, labels = labels, colors = colors,shadow = True, startangle = 90)
plt.legend(labels)
plt.title("Tweets analysed by sentiment")
plt.axis('equal')
plt.show()

# %%
def create_wordcloud(text):
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color = "white", max_words = 3000, stopwords = stopwords, repeat = True)
    wc.generate(str(text))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.show()
#word cloud for positive sentiments
create_wordcloud(tweet_pos["clean_text"].values)
#wordcloud for negative sentimenst
create_wordcloud(tweet_neg["clean_text"].values)
